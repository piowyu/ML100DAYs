# %%
import pandas as pd
import numpy as np

# %%
boston = pd.read_csv('boston.csv')

# %%
boston.plot.box(figsize = (12,10))                 #1,TAX
# Out:
# <AxesSubplot:>

# %%
boston.plot.scatter(x='NOX',y='DIS')            #2,負相關
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='DIS'>
